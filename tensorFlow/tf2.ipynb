# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sbn

# %%
df=pd.read_excel("merc.xlsx")
df.head(10)
# Out:
#    year   price transmission  mileage  tax   mpg  engineSize
# 0  2005    5200    Automatic    63000  325  32.1         1.8
# 1  2017   34948    Automatic    27000   20  61.4         2.1
# 2  2016   49948    Automatic     6200  555  28.0         5.5
# 3  2016   61948    Automatic    16000  325  30.4         4.0
# 4  2016   73948    Automatic     4000  325  30.1         4.0
# 5  2011  149948    Automatic     3000  570  21.4         6.2
# 6  2018   30948    Automatic    16000  145  47.9         2.1
# 7  2012   10948    Automatic   107000  265  36.7         3.5
# 8  2019  139948    Automatic    12000  145  21.4         4.0
# 9  2017   19750    Automatic    15258   30  64.2         2.1

# %%
df.describe()
# Out:
#                year          price        mileage           tax           mpg  \
# count  13119.000000   13119.000000   13119.000000  13119.000000  13119.000000
# mean    2017.296288   24698.596920   21949.559037    129.972178     55.155843
# std        2.224709   11842.675542   21176.512267     65.260286     15.220082
# min     1970.000000     650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000   17450.000000    6097.500000    125.000000     45.600000
# 50%     2018.000000   22480.000000   15189.000000    145.000000     56.500000
# 75%     2019.000000   28980.000000   31779.500000    145.000000     64.200000
# max     2020.000000  159999.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  13119.000000
# mean       2.071530
# std        0.572426
# min        0.000000
# 25%        1.800000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
df.isnull().sum()
# Out:
# year            0
# price           0
# transmission    0
# mileage         0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %%
# sbn.countplot(df["year"])
sbn.distplot(df["price"])
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_21408\3140518693.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sbn.distplot(df["price"])
# <Axes: xlabel='price', ylabel='Density'>

# %%
#sayisal olmayan degerleri cikarip korealasyon hesabı yapalım
dfNumeric=df.drop(columns=["transmission"],axis=1)

dfNumeric.corr()
# Out:
#                 year     price   mileage       tax       mpg  engineSize
# year        1.000000  0.520712 -0.738027  0.012480 -0.094626   -0.142147
# price       0.520712  1.000000 -0.537214  0.268717 -0.438445    0.516126
# mileage    -0.738027 -0.537214  1.000000 -0.160223  0.202850    0.063652
# tax         0.012480  0.268717 -0.160223  1.000000 -0.513742    0.338341
# mpg        -0.094626 -0.438445  0.202850 -0.513742  1.000000   -0.339862
# engineSize -0.142147  0.516126  0.063652  0.338341 -0.339862    1.000000

# %%
dfNumeric.corr()["tax"]
# Out:
# year          0.012480
# price         0.268717
# mileage      -0.160223
# tax           1.000000
# mpg          -0.513742
# engineSize    0.338341
# Name: tax, dtype: float64

# %%
dfNumeric.corr()["engineSize"]
# Out:
# year         -0.142147
# price         0.516126
# mileage       0.063652
# tax           0.338341
# mpg          -0.339862
# engineSize    1.000000
# Name: engineSize, dtype: float64

# %%
dfNumeric.corr()["year"].sort_values()
# Out:
# mileage      -0.738027
# engineSize   -0.142147
# mpg          -0.094626
# tax           0.012480
# price         0.520712
# year          1.000000
# Name: year, dtype: float64

# %%
sbn.scatterplot(x="mileage",y="price",data=dfNumeric)
# Out:
# <Axes: xlabel='mileage', ylabel='price'>

# %%
dfNumeric
# Out:
#        year  price  mileage  tax   mpg  engineSize
# 0      2005   5200    63000  325  32.1         1.8
# 1      2017  34948    27000   20  61.4         2.1
# 2      2016  49948     6200  555  28.0         5.5
# 3      2016  61948    16000  325  30.4         4.0
# 4      2016  73948     4000  325  30.1         4.0
# ...     ...    ...      ...  ...   ...         ...
# 13114  2020  35999      500  145  55.4         2.0
# 13115  2020  24699     2500  145  55.4         2.0
# 13116  2019  30999    11612  145  41.5         2.1
# 13117  2019  37990     2426  145  45.6         2.0
# 13118  2019  54999     2075  145  52.3         2.9
#
# [13119 rows x 6 columns]

# %%
dfNumeric.sort_values("price",ascending=True).head(20)
# Out:
#        year  price  mileage  tax   mpg  engineSize
# 11816  2003    650   109090  235  40.0         1.4
# 12008  2010   1350   116126  145  54.3         2.0
# 11765  2000   1490    87000  265  27.2         3.2
# 11549  2002   1495    13800  305  39.8         2.7
# 12594  2004   1495   119000  300  34.5         1.8
# 11174  2001   1695   108800  325  31.7         3.2
# 12710  2006   1695   153000  300  33.6         1.8
# 12766  2004   1780   118000  265  41.5         2.2
# 12009  2007   1800    84000  200  42.8         1.5
# 11764  1998   1990    99300  265  32.1         2.3
# 11808  1998   1990   113557  265  32.1         2.3
# 11383  2005   1995   105000  260  43.5         2.1
# 11378  2004   1995   165000  330  20.0         3.7
# 11857  2002   2140    52700  325  31.4         2.0
# 11906  2007   2478    81000  160  49.6         2.0
# 11795  2005   2490   101980  200  47.9         2.0
# 12765  2004   2495   104000  325  31.7         1.8
# ...

# %%
dfNumeric.sort_values("engineSize",ascending=True).head(10)
# Out:
#        year  price  mileage  tax   mpg  engineSize
# 10815  2017  18000    33282  145  68.9         0.0
# 10739  2017  16000    34635   30  64.2         0.0
# 9618   2016  17500    29712   20  68.9         0.0
# 9619   2018  20500    13386  145  53.3         0.0
# 11347  2007   4500    94000  520  29.4         0.0
# 9621   2018  18000    18347  150  65.7         0.0
# 10710  2018  17500    19796  145  74.3         0.0
# 12072  1970  24999    14000  305  39.2         0.0
# 10675  2016  16500    26955   30  70.6         0.0
# 11183  2018  22738    24000  150  61.4         0.0

# %%
len(df)
# Out:
# 13119

# %%
len(df)*0.01
#verinin yüzde 1 ini atarsak sorun olmaz. Absürt degerleri atalim
# Out:
# 131.19

# %%
ninetyNinePercentage=dfNumeric.sort_values("price",ascending=False).iloc[131:]
ninetyNinePercentage
# Out:
#        year  price  mileage  tax   mpg  engineSize
# 6177   2019  65990     5076  150  30.4         3.0
# 5779   2020  65990      999  145  28.0         4.0
# 3191   2020  65980     3999  145  28.0         4.0
# 4727   2019  65000     3398  145  27.2         4.0
# 8814   2019  64999      119  145  40.9         3.0
# ...     ...    ...      ...  ...   ...         ...
# 11549  2002   1495    13800  305  39.8         2.7
# 12594  2004   1495   119000  300  34.5         1.8
# 11765  2000   1490    87000  265  27.2         3.2
# 12008  2010   1350   116126  145  54.3         2.0
# 11816  2003    650   109090  235  40.0         1.4
#
# [12988 rows x 6 columns]

# %%
ninetyNinePercentage.describe()
# Out:
#                year         price        mileage           tax           mpg  \
# count  12988.000000  12988.000000   12988.000000  12988.000000  12988.000000
# mean    2017.281876  24074.926933   22132.741146    129.689714     55.437142
# std        2.228515   9866.224575   21196.776401     65.183076     15.025999
# min     1970.000000    650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000  17357.500000    6322.000000    125.000000     45.600000
# 50%     2018.000000  22299.000000   15369.500000    145.000000     56.500000
# 75%     2019.000000  28706.000000   31982.250000    145.000000     64.200000
# max     2020.000000  65990.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  12988.000000
# mean       2.050901
# std        0.532596
# min        0.000000
# 25%        1.675000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
sbn.distplot(ninetyNinePercentage["price"])
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_21408\1247077021.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sbn.distplot(ninetyNinePercentage["price"])
# <Axes: xlabel='price', ylabel='Density'>

# %%
#veriyi yıllara göre gruplayıp fiyat ortalaması al
dfNumeric.groupby("year").mean()["price"]
# Out:
# year
# 1970    24999.000000
# 1997     9995.000000
# 1998     8605.000000
# 1999     5995.000000
# 2000     5743.333333
# 2001     4957.900000
# 2002     5820.444444
# 2003     4878.000000
# 2004     4727.615385
# 2005     4426.111111
# 2006     4036.875000
# 2007     5136.045455
# 2008     6967.437500
# 2009     6166.764706
# 2010     8308.473684
# 2011    12624.894737
# 2012    10845.140351
# 2013    11939.842466
# 2014    14042.936864
# 2015    16731.780020
# 2016    19307.892948
# 2017    21514.307854
# 2018    25720.162918
# 2019    31290.020865
# 2020    35433.282337
# Name: price, dtype: float64

# %%
#1970 deki arabalar çok özel bi değişken verinin gidişatını bozuyor onu bi çıkar
dfNumeric[dfNumeric["year"]!=1970].groupby("year").mean()["price"]
# Out:
# year
# 1997     9995.000000
# 1998     8605.000000
# 1999     5995.000000
# 2000     5743.333333
# 2001     4957.900000
# 2002     5820.444444
# 2003     4878.000000
# 2004     4727.615385
# 2005     4426.111111
# 2006     4036.875000
# 2007     5136.045455
# 2008     6967.437500
# 2009     6166.764706
# 2010     8308.473684
# 2011    12624.894737
# 2012    10845.140351
# 2013    11939.842466
# 2014    14042.936864
# 2015    16731.780020
# 2016    19307.892948
# 2017    21514.307854
# 2018    25720.162918
# 2019    31290.020865
# 2020    35433.282337
# Name: price, dtype: float64

# %%
dfNumeric[dfNumeric.year!=1970].groupby("year").mean()["price"]
# Out:
# year
# 1997     9995.000000
# 1998     8605.000000
# 1999     5995.000000
# 2000     5743.333333
# 2001     4957.900000
# 2002     5820.444444
# 2003     4878.000000
# 2004     4727.615385
# 2005     4426.111111
# 2006     4036.875000
# 2007     5136.045455
# 2008     6967.437500
# 2009     6166.764706
# 2010     8308.473684
# 2011    12624.894737
# 2012    10845.140351
# 2013    11939.842466
# 2014    14042.936864
# 2015    16731.780020
# 2016    19307.892948
# 2017    21514.307854
# 2018    25720.162918
# 2019    31290.020865
# 2020    35433.282337
# Name: price, dtype: float64

# %%
df=ninetyNinePercentage
df
# Out:
#        year  price  mileage  tax   mpg  engineSize
# 6177   2019  65990     5076  150  30.4         3.0
# 5779   2020  65990      999  145  28.0         4.0
# 3191   2020  65980     3999  145  28.0         4.0
# 4727   2019  65000     3398  145  27.2         4.0
# 8814   2019  64999      119  145  40.9         3.0
# ...     ...    ...      ...  ...   ...         ...
# 11549  2002   1495    13800  305  39.8         2.7
# 12594  2004   1495   119000  300  34.5         1.8
# 11765  2000   1490    87000  265  27.2         3.2
# 12008  2010   1350   116126  145  54.3         2.0
# 11816  2003    650   109090  235  40.0         1.4
#
# [12988 rows x 6 columns]

# %%
df=df[df["year"]>1970]
df
# Out:
#        year  price  mileage  tax   mpg  engineSize
# 6177   2019  65990     5076  150  30.4         3.0
# 5779   2020  65990      999  145  28.0         4.0
# 3191   2020  65980     3999  145  28.0         4.0
# 4727   2019  65000     3398  145  27.2         4.0
# 8814   2019  64999      119  145  40.9         3.0
# ...     ...    ...      ...  ...   ...         ...
# 11549  2002   1495    13800  305  39.8         2.7
# 12594  2004   1495   119000  300  34.5         1.8
# 11765  2000   1490    87000  265  27.2         3.2
# 12008  2010   1350   116126  145  54.3         2.0
# 11816  2003    650   109090  235  40.0         1.4
#
# [12987 rows x 6 columns]

# %%
df.groupby("year").mean()["price"]
# Out:
# year
# 1997     9995.000000
# 1998     8605.000000
# 1999     5995.000000
# 2000     5743.333333
# 2001     4957.900000
# 2002     5820.444444
# 2003     4878.000000
# 2004     4727.615385
# 2005     4426.111111
# 2006     4036.875000
# 2007     5136.045455
# 2008     6967.437500
# 2009     6166.764706
# 2010     8308.473684
# 2011     8913.459459
# 2012    10845.140351
# 2013    11939.842466
# 2014    14042.936864
# 2015    16647.822222
# 2016    19223.558943
# 2017    21356.280421
# 2018    24800.844506
# 2019    30289.524832
# 2020    34234.794872
# Name: price, dtype: float64

# %%
df.head(5)
# Out:
#       year  price  mileage  tax   mpg  engineSize
# 6177  2019  65990     5076  150  30.4         3.0
# 5779  2020  65990      999  145  28.0         4.0
# 3191  2020  65980     3999  145  28.0         4.0
# 4727  2019  65000     3398  145  27.2         4.0
# 8814  2019  64999      119  145  40.9         3.0

# %%
y=df["price"].values
#bunu numpy dizisine cevirdik
y
# Out:
# array([65990, 65990, 65980, ...,  1490,  1350,   650], dtype=int64)

# %%
x=df.drop("price",axis=1).values
x
# Out:
# array([[2.01900e+03, 5.07600e+03, 1.50000e+02, 3.04000e+01, 3.00000e+00],
#        [2.02000e+03, 9.99000e+02, 1.45000e+02, 2.80000e+01, 4.00000e+00],
#        [2.02000e+03, 3.99900e+03, 1.45000e+02, 2.80000e+01, 4.00000e+00],
#        ...,
#        [2.00000e+03, 8.70000e+04, 2.65000e+02, 2.72000e+01, 3.20000e+00],
#        [2.01000e+03, 1.16126e+05, 1.45000e+02, 5.43000e+01, 2.00000e+00],
#        [2.00300e+03, 1.09090e+05, 2.35000e+02, 4.00000e+01, 1.40000e+00]])

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=10)

# %%
len(x_train)
# Out:
# 9090

# %%
len(x_test)
# Out:
# 3897

# %%
from sklearn.preprocessing import MinMaxScaler

scaler=MinMaxScaler()

# %%
x_train=scaler.fit_transform(x_train)
x_test=scaler.fit_transform(x_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
x_train.shape
#burada koyacağımız layerları 5 den başlatsak iyi olur
# Out:
# (9090, 5)

# %%
model=Sequential()

model.add(Dense(12,activation="relu"))
model.add(Dense(12,activation="relu"))
model.add(Dense(12,activation="relu"))
model.add(Dense(12,activation="relu"))

model.add(Dense(1))

model.compile(optimizer="adam",loss="mse")

# %%
model.fit(x=x_train,y=y_train,validation_data=(x_test,y_test),batch_size=250,epochs=300)
# Out:
# Epoch 1/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 672954752.0000 - val_loss: 688386048.0000
# Epoch 2/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 676298880.0000 - val_loss: 688327232.0000
# Epoch 3/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 668937024.0000 - val_loss: 688153280.0000
# Epoch 4/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 672750464.0000 - val_loss: 687603968.0000
# Epoch 5/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 671506368.0000 - val_loss: 686086912.0000
# Epoch 6/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 669738240.0000 - val_loss: 682523712.0000
# Epoch 7/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 669222528.0000 - val_loss: 675172224.0000
# Epoch 8/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 662128896.0000 - val_loss: 661599872.0000
# Epoch 9/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 627477824.0000 - val_loss: 638672320.0000
# Epoch 10/300
# ...

# %%
lossData=pd.DataFrame(model.history.history)
lossData
# Out:
#             loss     val_loss
# 0    674969920.0  688386048.0
# 1    671540992.0  688327232.0
# 2    671011456.0  688153280.0
# 3    671566336.0  687603968.0
# 4    669665088.0  686086912.0
# ..           ...          ...
# 295   18614092.0   22095466.0
# 296   18610834.0   22275162.0
# 297   18540956.0   22527424.0
# 298   18527718.0   22120048.0
# 299   18646642.0   22547438.0
#
# [300 rows x 2 columns]

# %%
lossData.plot()
# Out:
# <Axes: >

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

prediction=model.predict(x_test)
# Out:
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
prediction
# Out:
# array([[20396.576],
#        [22025.64 ],
#        [24483.287],
#        ...,
#        [24870.975],
#        [10760.566],
#        [24021.203]], dtype=float32)

# %%
mean_absolute_error(y_test,prediction)
# Out:
# 3382.478327178759

# %%
plt.scatter(y_test,prediction)
plt.plot(y_test,y_test,"g*-")

# %%
df.head()
# Out:
#       year  price  mileage  tax   mpg  engineSize
# 6177  2019  65990     5076  150  30.4         3.0
# 5779  2020  65990      999  145  28.0         4.0
# 3191  2020  65980     3999  145  28.0         4.0
# 4727  2019  65000     3398  145  27.2         4.0
# 8814  2019  64999      119  145  40.9         3.0

# %%
df.iloc[2]
# Out:
# year           2020.0
# price         65980.0
# mileage        3999.0
# tax             145.0
# mpg              28.0
# engineSize        4.0
# Name: 3191, dtype: float64

# %%
series=df.drop("price",axis=1).iloc[2]
#price sütunu olmayan 2 indexli özelliklerden series oluşturur 
series
# Out:
# year          2020.0
# mileage       3999.0
# tax            145.0
# mpg             28.0
# engineSize       4.0
# Name: 3191, dtype: float64

# %%
series=scaler.transform(series.values.reshape(-1,5))

# %%
model.predict(series)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# array([[60755.16]], dtype=float32)
